# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import matplotlib.pyplot as plt
from src.basic_model import simulate_model

# %%
# Set parameters
beta = 0.8   # Spreading rate
gamma = 0.2  # Stifling rate

# Simulate
t, result = simulate_model(beta, gamma)

# Plotting
plt.figure(figsize=(10,6))
plt.plot(t, result[:, 0], label='Ignorants (I)')
plt.plot(t, result[:, 1], label='Spreaders (S)')
plt.plot(t, result[:, 2], label='Stiflers (R)')
plt.xlabel('Time (days)')
plt.ylabel('Fraction of population')
plt.title('Basic News Spread Simulation')
plt.legend()
plt.grid(True)
plt.show()
